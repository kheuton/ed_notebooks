# %%
import json
import vincent

# %%
geo_data = json.load(open('./my_layer.json','rb'))

# %%
world = vincent.Map(width=1200, height=1000,geo_data = geo_data, projection='albersUsa')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-01ba21bcf3b6> in <module>()
# ----> 1 world = vincent.Map(width=1200, height=1000,geo_data = geo_data, projection='albersUsa')
#
# /home/krheuton/anaconda2/lib/python2.7/site-packages/vincent-0.4.4-py2.7.egg/vincent/charts.py in __init__(self, data, geo_data, projection, center, translate, scale, rotate, data_bind, data_key, map_key, brew, *args, **kwargs)
#     438             transforms.append(geo_transform)
#     439             self.data[dat['name']] = Data(
# --> 440                 name=dat['name'], url=dat['url'], transform=transforms
#     441                 )
#     442             if dat.get('feature'):
#
# TypeError: string indices must be integers

# %%
geo_data
# Out:
# {u'crs': {u'properties': {u'href': u'http://spatialreference.org/ref/epsg/2926/esriwkt/',
#    u'type': u'esriwkt'},
#   u'type': u'link'},
#  u'features': [{u'geometry': {u'coordinates': [[[1260267.4882409072,
#        253541.20624608826],
#       [1260258.5824034074, 253031.63841912942],
#       [1260246.930877459, 252376.98587366613],
#       [1260246.2287764498, 252341.97543415055],
#       [1260234.1323282004, 251690.16901167063],
#       [1260233.056128708, 251629.70719778654],
#       [1260226.76629278, 251276.33043763228],
#       [1260221.7738183863, 251016.3119227921],
#       [1260220.1652083474, 250925.11508062948],
#       [1260219.0730611768, 250863.19902664702],
#       [1260216.4007947631, 250650.73259065393],
#       [1260215.5261362928, 250650.41175562376],
#       [1260214.4670939934, 250586.86106463335],
#       [1260214.4483689107, 250585.73814202775],
#       [1260213.602246033, 250534.99070396507],
#       [1260214.2003287596, 250522.5898163321],
# ...
